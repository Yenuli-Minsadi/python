# %%
my_tuple = ("Tennis",)

print(my_tuple)
print(type(my_tuple))
# Out:
# ('Tennis',)
# <class 'tuple'>

# %%
sports = ("tennis",10,"cricket")
sports[2] = "football"

print(sports)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 sports = ("tennis",10,"cricket")
# ----> 2 sports[2] = "football"
#       3
#       4 print(sports)
#
# TypeError: 'tuple' object does not support item assignment

# %%
sports = ("tennis",10,"cricket")
my_list = list(sports)
print(my_list)
my_list[2]="football"
print(my_list)
sports=tuple(my_list)
print(sports)
# Out:
# ['tennis', 10, 'cricket']
# ['tennis', 10, 'football']
# ('tennis', 10, 'football')
